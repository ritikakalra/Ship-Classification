# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikakalra/Ship-Classification/blob/master/Creating_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NOTEBOOK 1**
#
# **CREATING DATASET**

# %% [markdown]
# Importing kaggle.json file.
#
# Required for interacting with Kaggle.

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-da0dfa57-198d-4375-af7f-d228806ed2b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da0dfa57-198d-4375-af7f-d228806ed2b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %% [markdown]
# ## Setting up environment virables, so that kaggle api can work properly.

# %%
import os
import pandas as pd
cred = pd.read_json("kaggle.json",lines=True)
os.environ['KAGGLE_USERNAME'] = cred.iloc[0][0]
os.environ['KAGGLE_KEY'] = cred.iloc[0][1]

# %% [markdown]
# Downloading dataset from Kaggle.

# %%
# !kaggle datasets download -d john2468basha/johnnyships
# Out:
# ...
#  94% 152M/162M [00:01<00:00, 98.0MB/s]
# 100% 162M/162M [00:01<00:00, 101MB/s]

# %% [markdown]
# Unzipping the downloaded data.

# %%
# !unzip "*.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: johnny_ships_new/images/train/1/2835446.jpg
#   inflating: johnny_ships_new/images/train/1/2835451.jpg
#   inflating: johnny_ships_new/images/train/1/2835452.jpg
#   inflating: johnny_ships_new/images/train/1/2835453.jpg
#   inflating: johnny_ships_new/images/train/1/2835454.jpg
#   inflating: johnny_ships_new/images/train/1/2835460.jpg
#   inflating: johnny_ships_new/images/train/1/2835465.jpg
#   inflating: johnny_ships_new/images/train/1/2835466.jpg
#   inflating: johnny_ships_new/images/train/1/2835467.jpg
#   inflating: johnny_ships_new/images/train/1/2835468.jpg
#   inflating: johnny_ships_new/images/train/1/2835475.jpg
#   inflating: johnny_ships_new/images/train/1/2835479.jpg
#   inflating: johnny_ships_new/images/train/1/2835480.jpg
#   inflating: johnny_ships_new/images/train/1/2835481.jpg
#   inflating: johnny_ships_new/images/train/1/2835483.jpg
#   inflating: johnny_ships_new/images/train/1/2835484.jpg
# ...

# %%
os.listdir("/content/images/train")
# Out:
# ['4', '2', '5', '1', '3']

# %% [markdown]
# Next step, **uploading the dataset to our kaggle account**.
#
# *Generating metadata.json file.*

# %%
# !kaggle datasets init -p /content
# Out:
# Data package template written to: /content/dataset-metadata.json

# %% [markdown]
# Now, Uploading.
#
# -r zip : directory mode; compressed upload.

# %%
# !kaggle datasets create -p /content -u -r zip
# Out:
# Starting upload for file .config.zip
# ...
# 100% 6.71k/6.71k [00:01<00:00, 4.84kB/s]
# Upload successful: .config.zip (7KB)
# Starting upload for file johnnyships.zip
# 100% 162M/162M [00:02<00:00, 63.5MB/s]
# Upload successful: johnnyships.zip (162MB)
# Starting upload for file images.zip
# 100% 80.4M/80.4M [00:02<00:00, 40.8MB/s]
# Upload successful: images.zip (80MB)
# Starting upload for file kaggle.json
# 100% 67.0/67.0 [00:01<00:00, 41.4B/s]
# Upload successful: kaggle.json (67B)
# Starting upload for file johnny_ships_new.zip
# 100% 80.6M/80.6M [00:01<00:00, 45.1MB/s]
# Upload successful: johnny_ships_new.zip (81MB)
# Starting upload for file sample_data.zip
# 100% 6.74M/6.74M [00:01<00:00, 4.37MB/s]
# Upload successful: sample_data.zip (7MB)
# Your public Dataset is being created. Please check progress at https://www.kaggle.com/ritikakalra/ship-images
